# %%
#Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split,KFold,cross_val_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV,LassoCV,ElasticNetCV
from xgboost import XGBRegressor
from sklearn.preprocessing import RobustScaler, PowerTransformer, StandardScaler, MinMaxScaler

# %%
#Reading train and test dataset in dataframe
train = pd.read_excel("Flight_Train.xlsx")
test = pd.read_excel("Flight_Test.xlsx")

# %%
#Appending both trian and test to df
df = train.append(test)

# %%
#Displayes first five rows of dataset by default
df.head()
# Out:
#   Additional_Info      Airline  Arrival_Time Date_of_Journey Dep_Time  \
# 0         No info       IndiGo  01:10 22 Mar      24/03/2019    22:20
# 1         No info    Air India         13:15       1/05/2019    05:50
# 2         No info  Jet Airways  04:25 10 Jun       9/06/2019    09:25
# 3         No info       IndiGo         23:30      12/05/2019    18:05
# 4         No info       IndiGo         21:35      01/03/2019    16:50
#
#   Destination Duration    Price                  Route    Source Total_Stops
# 0   New Delhi   2h 50m   3897.0              BLR → DEL  Banglore    non-stop
# 1    Banglore   7h 25m   7662.0  CCU → IXR → BBI → BLR   Kolkata     2 stops
# 2      Cochin      19h  13882.0  DEL → LKO → BOM → COK     Delhi     2 stops
# 3    Banglore   5h 25m   6218.0        CCU → NAG → BLR   Kolkata      1 stop
# 4   New Delhi   4h 45m  13302.0        BLR → NAG → DEL  Banglore      1 stop

# %%
#To check dimension
df.shape
# Out:
# (13354, 11)

# %%
#Checking for missing values, dtypes, total count, unique count
missing_value = pd.DataFrame(df.dtypes)
missing_value.rename(columns={0:'DataTypes'},inplace=True)
missing_value['Count'] = df.count()
missing_value['Unique values'] = df.nunique()
missing_value['Null Value Count'] = df.isna().sum()
missing_value['Missing value %'] = df.isna().mean().round(2)*100

# %%
missing_value
# Out:
#                 DataTypes  Count  Unique values  Null Value Count  \
# Additional_Info    object  13354             10                 0
# Airline            object  13354             12                 0
# Arrival_Time       object  13354           1451                 0
# Date_of_Journey    object  13354             44                 0
# Dep_Time           object  13354            223                 0
# Destination        object  13354              6                 0
# Duration           object  13354            374                 0
# Price             float64  10683           1870              2671
# Route              object  13353            132                 1
# Source             object  13354              5                 0
# Total_Stops        object  13353              5                 1
#
#                  Missing value %
# Additional_Info              0.0
# Airline                      0.0
# Arrival_Time                 0.0
# Date_of_Journey              0.0
# Dep_Time                     0.0
# Destination                  0.0
# Duration                     0.0
# Price                       20.0
# Route                        0.0
# Source                       0.0
# Total_Stops                  0.0

# %%
#Filling missing values with 'ffill' method
df['Price'] = df['Price'].fillna(method='ffill')

# %%
#Dropping remaining missing values as it totally 2
df.dropna(inplace=True)

# %%
df.head()
# Out:
#   Additional_Info      Airline  Arrival_Time Date_of_Journey Dep_Time  \
# 0         No info       IndiGo  01:10 22 Mar      24/03/2019    22:20
# 1         No info    Air India         13:15       1/05/2019    05:50
# 2         No info  Jet Airways  04:25 10 Jun       9/06/2019    09:25
# 3         No info       IndiGo         23:30      12/05/2019    18:05
# 4         No info       IndiGo         21:35      01/03/2019    16:50
#
#   Destination Duration    Price                  Route    Source Total_Stops
# 0   New Delhi   2h 50m   3897.0              BLR → DEL  Banglore    non-stop
# 1    Banglore   7h 25m   7662.0  CCU → IXR → BBI → BLR   Kolkata     2 stops
# 2      Cochin      19h  13882.0  DEL → LKO → BOM → COK     Delhi     2 stops
# 3    Banglore   5h 25m   6218.0        CCU → NAG → BLR   Kolkata      1 stop
# 4   New Delhi   4h 45m  13302.0        BLR → NAG → DEL  Banglore      1 stop

# %%
#displayes non null value count and dtype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13353 entries, 0 to 2670
# Data columns (total 11 columns):
# Additional_Info    13353 non-null object
# Airline            13353 non-null object
# Arrival_Time       13353 non-null object
# Date_of_Journey    13353 non-null object
# Dep_Time           13353 non-null object
# Destination        13353 non-null object
# Duration           13353 non-null object
# Price              13353 non-null float64
# Route              13353 non-null object
# Source             13353 non-null object
# Total_Stops        13353 non-null object
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
# # Feature Extraction

# %%
#We going to extract date and month from Data_of_journey and convert to Datetime Object
df['Journey_Date'] = pd.to_datetime(df["Date_of_Journey"]).dt.day

# %%
df['Journey_Month'] = pd.to_datetime(df["Date_of_Journey"]).dt.month

# %%
df.drop(['Date_of_Journey'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Additional_Info      Airline  Arrival_Time Dep_Time Destination Duration  \
# 0         No info       IndiGo  01:10 22 Mar    22:20   New Delhi   2h 50m
# 1         No info    Air India         13:15    05:50    Banglore   7h 25m
# 2         No info  Jet Airways  04:25 10 Jun    09:25      Cochin      19h
# 3         No info       IndiGo         23:30    18:05    Banglore   5h 25m
# 4         No info       IndiGo         21:35    16:50   New Delhi   4h 45m
#
#      Price                  Route    Source Total_Stops  Journey_Date  \
# 0   3897.0              BLR → DEL  Banglore    non-stop            24
# 1   7662.0  CCU → IXR → BBI → BLR   Kolkata     2 stops             5
# 2  13882.0  DEL → LKO → BOM → COK     Delhi     2 stops             6
# 3   6218.0        CCU → NAG → BLR   Kolkata      1 stop             5
# 4  13302.0        BLR → NAG → DEL  Banglore      1 stop             3
#
#    Journey_Month
# 0              3
# 1              1
# 2              9
# 3             12
# 4              1

# %%
#In Arival column we only need time not month and extract to hour and minute, changing dtype to int
df["Arrival_Time"] = df["Arrival_Time"].str.split(' ').str[0]
df["Arrival_Hour"] = df["Arrival_Time"].str.split(':').str[0].astype(int)
df["Arrival_Minute"] = df["Arrival_Time"].str.split(':').str[1].astype(int)
df.drop('Arrival_Time',axis=1,inplace=True)

# %%
#Extracting hour and min from Dep_Time
df['Dep_Hour'] = df['Dep_Time'].str.split(':').str[0].astype(int)
df['Dep_Minute'] = df['Dep_Time'].str.split(':').str[1].astype(int)
df.drop('Dep_Time',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Additional_Info      Airline Destination Duration    Price  \
# 0         No info       IndiGo   New Delhi   2h 50m   3897.0
# 1         No info    Air India    Banglore   7h 25m   7662.0
# 2         No info  Jet Airways      Cochin      19h  13882.0
# 3         No info       IndiGo    Banglore   5h 25m   6218.0
# 4         No info       IndiGo   New Delhi   4h 45m  13302.0
#
#                    Route    Source Total_Stops  Journey_Date  Journey_Month  \
# 0              BLR → DEL  Banglore    non-stop            24              3
# 1  CCU → IXR → BBI → BLR   Kolkata     2 stops             5              1
# 2  DEL → LKO → BOM → COK     Delhi     2 stops             6              9
# 3        CCU → NAG → BLR   Kolkata      1 stop             5             12
# 4        BLR → NAG → DEL  Banglore      1 stop             3              1
#
#    Arrival_Hour  Arrival_Minute  Dep_Hour  Dep_Minute
# 0             1              10        22          20
# 1            13              15         5          50
# 2             4              25         9          25
# 3            23              30        18           5
# 4            21              35        16          50

# %%
#We only need number of stops not with string
df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
'''Replacing non-stop with 0 stop'''
df['Total_Stops'] = df['Total_Stops'].replace({'non-stop':'0 stop'})

# %%
df['Total_Stops'] = df['Total_Stops'].str.split(' ').str[0].astype(int)

# %%
df.head()
# Out:
#   Additional_Info      Airline Destination Duration    Price  \
# 0         No info       IndiGo   New Delhi   2h 50m   3897.0
# 1         No info    Air India    Banglore   7h 25m   7662.0
# 2         No info  Jet Airways      Cochin      19h  13882.0
# 3         No info       IndiGo    Banglore   5h 25m   6218.0
# 4         No info       IndiGo   New Delhi   4h 45m  13302.0
#
#                    Route    Source  Total_Stops  Journey_Date  Journey_Month  \
# 0              BLR → DEL  Banglore            0            24              3
# 1  CCU → IXR → BBI → BLR   Kolkata            2             5              1
# 2  DEL → LKO → BOM → COK     Delhi            2             6              9
# 3        CCU → NAG → BLR   Kolkata            1             5             12
# 4        BLR → NAG → DEL  Banglore            1             3              1
#
#    Arrival_Hour  Arrival_Minute  Dep_Hour  Dep_Minute
# 0             1              10        22          20
# 1            13              15         5          50
# 2             4              25         9          25
# 3            23              30        18           5
# 4            21              35        16          50

# %%
'''
The ‘Route’ columns mainly tell us that how many cities they have taken to reach from source to destination .
This column is very important because based on the route they took will directly effect the price of the flight So We 
split the Route column to extract the information .Regarding the ‘Nan’ values we replace those ‘Nan’ values with ‘None’
'''
df["Route_1"] = df["Route"].str.split('→ ').str[0]
df["Route_2"] = df["Route"].str.split('→ ').str[1]
df["Route_3"] = df["Route"].str.split('→ ').str[2]
df["Route_4"] = df["Route"].str.split('→ ').str[3]
df["Route_5"] = df["Route"].str.split('→ ').str[4]

# %%
df.head()
# Out:
#   Additional_Info      Airline Destination Duration    Price  \
# 0         No info       IndiGo   New Delhi   2h 50m   3897.0
# 1         No info    Air India    Banglore   7h 25m   7662.0
# 2         No info  Jet Airways      Cochin      19h  13882.0
# 3         No info       IndiGo    Banglore   5h 25m   6218.0
# 4         No info       IndiGo   New Delhi   4h 45m  13302.0
#
#                    Route    Source  Total_Stops  Journey_Date  Journey_Month  \
# 0              BLR → DEL  Banglore            0            24              3
# 1  CCU → IXR → BBI → BLR   Kolkata            2             5              1
# 2  DEL → LKO → BOM → COK     Delhi            2             6              9
# 3        CCU → NAG → BLR   Kolkata            1             5             12
# 4        BLR → NAG → DEL  Banglore            1             3              1
#
#    Arrival_Hour  Arrival_Minute  Dep_Hour  Dep_Minute Route_1 Route_2 Route_3  \
# 0             1              10        22          20    BLR      DEL     NaN
# 1            13              15         5          50    CCU     IXR     BBI
# 2             4              25         9          25    DEL     LKO     BOM
# 3            23              30        18           5    CCU     NAG      BLR
# 4            21              35        16          50    BLR     NAG      DEL
#
#   Route_4 Route_5
# 0     NaN     NaN
# 1     BLR     NaN
# 2     COK     NaN
# 3     NaN     NaN
# 4     NaN     NaN

# %%
#Filling NaN value in Route column as None
df['Route_1'].fillna('None',inplace=True)
df['Route_2'].fillna('None',inplace=True)
df['Route_3'].fillna('None',inplace=True)
df['Route_4'].fillna('None',inplace=True)
df['Route_5'].fillna('None',inplace=True)
df.drop('Route',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Additional_Info      Airline Destination Duration    Price    Source  \
# 0         No info       IndiGo   New Delhi   2h 50m   3897.0  Banglore
# 1         No info    Air India    Banglore   7h 25m   7662.0   Kolkata
# 2         No info  Jet Airways      Cochin      19h  13882.0     Delhi
# 3         No info       IndiGo    Banglore   5h 25m   6218.0   Kolkata
# 4         No info       IndiGo   New Delhi   4h 45m  13302.0  Banglore
#
#    Total_Stops  Journey_Date  Journey_Month  Arrival_Hour  Arrival_Minute  \
# 0            0            24              3             1              10
# 1            2             5              1            13              15
# 2            2             6              9             4              25
# 3            1             5             12            23              30
# 4            1             3              1            21              35
#
#    Dep_Hour  Dep_Minute Route_1 Route_2 Route_3 Route_4 Route_5
# 0        22          20    BLR      DEL    None    None    None
# 1         5          50    CCU     IXR     BBI      BLR    None
# 2         9          25    DEL     LKO     BOM      COK    None
# 3        18           5    CCU     NAG      BLR    None    None
# 4        16          50    BLR     NAG      DEL    None    None

# %%
df.dtypes
# Out:
# Additional_Info     object
# Airline             object
# Destination         object
# Duration            object
# Price              float64
# Source              object
# Total_Stops          int32
# Journey_Date         int64
# Journey_Month        int64
# Arrival_Hour         int32
# Arrival_Minute       int32
# Dep_Hour             int32
# Dep_Minute           int32
# Route_1             object
# Route_2             object
# Route_3             object
# Route_4             object
# Route_5             object
# dtype: object

# %%
#Removing Duration column as we have arrival and departure
df.drop('Duration',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Additional_Info      Airline Destination    Price    Source  Total_Stops  \
# 0         No info       IndiGo   New Delhi   3897.0  Banglore            0
# 1         No info    Air India    Banglore   7662.0   Kolkata            2
# 2         No info  Jet Airways      Cochin  13882.0     Delhi            2
# 3         No info       IndiGo    Banglore   6218.0   Kolkata            1
# 4         No info       IndiGo   New Delhi  13302.0  Banglore            1
#
#    Journey_Date  Journey_Month  Arrival_Hour  Arrival_Minute  Dep_Hour  \
# 0            24              3             1              10        22
# 1             5              1            13              15         5
# 2             6              9             4              25         9
# 3             5             12            23              30        18
# 4             3              1            21              35        16
#
#    Dep_Minute Route_1 Route_2 Route_3 Route_4 Route_5
# 0          20    BLR      DEL    None    None    None
# 1          50    CCU     IXR     BBI      BLR    None
# 2          25    DEL     LKO     BOM      COK    None
# 3           5    CCU     NAG      BLR    None    None
# 4          50    BLR     NAG      DEL    None    None

# %%
#Converting categorical to numeical
df.select_dtypes(include='object').columns
# Out:
# Index(['Additional_Info', 'Airline', 'Destination', 'Source', 'Route_1',
#        'Route_2', 'Route_3', 'Route_4', 'Route_5'],
#       dtype='object')

# %%
def labelencode(a):
    #Lable Encoding all the categorical variable
    le=LabelEncoder()
    return le.fit_transform(a)
df['Additional_Info'] = labelencode(df['Additional_Info'])
df['Airline'] = labelencode(df['Airline'])
df['Destination'] = labelencode(df['Destination'])
df['Source'] = labelencode(df['Source'])
df['Route_1'] = labelencode(df['Route_1'])
df['Route_2'] = labelencode(df['Route_2'])
df['Route_3'] = labelencode(df['Route_3'])
df['Route_4'] = labelencode(df['Route_4'])
df['Route_5'] = labelencode(df['Route_5'])

# %%
df.head()
# Out:
#    Additional_Info  Airline  Destination    Price  Source  Total_Stops  \
# 0                8        3            5   3897.0       0            0
# 1                8        1            0   7662.0       3            2
# 2                8        4            1  13882.0       2            2
# 3                8        3            0   6218.0       3            1
# 4                8        3            5  13302.0       0            1
#
#    Journey_Date  Journey_Month  Arrival_Hour  Arrival_Minute  Dep_Hour  \
# 0            24              3             1              10        22
# 1             5              1            13              15         5
# 2             6              9             4              25         9
# 3             5             12            23              30        18
# 4             3              1            21              35        16
#
#    Dep_Minute  Route_1  Route_2  Route_3  Route_4  Route_5
# 0          20        0       13       24       12        4
# 1          50        2       25        1        3        4
# 2          25        3       32        4        5        4
# 3           5        2       34        3       12        4
# 4          50        0       34        8       12        4

# %%
df.shape
# Out:
# (13353, 17)

# %%
#Train Test split
x = df.drop('Price',axis=1)
y = df['Price']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((10682, 16), (2671, 16), (10682,), (2671,))

# %% [markdown]
# # Model Building

# %%
#Build our cross validation method by taking 50 folds
kfold = KFold(n_splits=50,shuffle=True,random_state=100)

#Calculating mean RMSE score
def cv_rmse(model):
    rmse = np.sqrt(-cross_val_score(model,x,y,
                                   scoring = 'neg_mean_squared_error',
                                   cv=kfold))
    return rmse

#Storing different scaler in a list to find out the best scaler for our model
scaler = [MinMaxScaler(),StandardScaler(),RobustScaler(),PowerTransformer()]

# %%
###LINEAR REGRESSION###
le = LinearRegression()

for i in scaler:
    lr_model = make_pipeline(i,
                     le).fit(X=x_train,y=y_train)
    print("The RMSE score by using {0} is ".format(i),cv_rmse(lr_model).mean())
warnings.filterwarnings("ignore")
# Out:
# The RMSE score by using MinMaxScaler(copy=True, feature_range=(0, 1)) is  3340.2504932334377
# The RMSE score by using StandardScaler(copy=True, with_mean=True, with_std=True) is  3340.2504932334377
# The RMSE score by using RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True) is  3340.2504932334386
# The RMSE score by using PowerTransformer(copy=True, method='yeo-johnson', standardize=True) is  3335.105599157023

# %% [markdown]
# '''
# As in Linear regression we may face overfit or underfit problem. To overcome underfitting we will increase model complexity,
# where we have High Bias and Low Variance, for overfitting we will use Regularisation technique where we have Low Bias and High
# Variance.
# '''

# %%
###LASSO###

#HyperParameter Tuning
alpha = [0.00005,0.0003,0.0001,0.0005,0.0007,0.0009,0.01] #Best values 
alpha1 = [0.0005,0.0003,0.0002,0.0004,0.0001,0.0005,0.0007,0.0008]

for i in scaler:
    lasso_model1 = make_pipeline(i,LassoCV(max_iter=1e7,
                                     alphas=alpha,
                                     random_state=40)).fit(X=x_train,y=y_train)
    lasso_model2 = make_pipeline(i,LassoCV(max_iter=1e7,
                                     alphas=alpha1,
                                     random_state=40)).fit(X=x_train,y=y_train)
    
    print('The RMSE value for {0} in Lasso Model1 is '.format(i),cv_rmse(lasso_model1).mean())
    print('The RMSE value for {0} in Lasso Model2 is '.format(i),cv_rmse(lasso_model2).mean())

#warnings.filterwarnings("ignore")
# Out:
# The RMSE value for MinMaxScaler(copy=True, feature_range=(0, 1)) in Lasso Model1 is  3340.247645298782
# The RMSE value for MinMaxScaler(copy=True, feature_range=(0, 1)) in Lasso Model2 is  3340.250261789389
# The RMSE value for StandardScaler(copy=True, with_mean=True, with_std=True) in Lasso Model1 is  3340.2497972908077
# The RMSE value for StandardScaler(copy=True, with_mean=True, with_std=True) in Lasso Model2 is  3340.2504375198423
# The RMSE value for RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True) in Lasso Model1 is  3340.249474709656
# The RMSE value for RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True) in Lasso Model2 is  3340.250410623268
# The RMSE value for PowerTransformer(copy=True, method='yeo-johnson', standardize=True) in Lasso Model1 is  3335.105194166887
# The RMSE value for PowerTransformer(copy=True, method='yeo-johnson', standardize=True) in Lasso Model2 is  3335.1055667280903

# %%
# Lasso alpha value(best value)
def lasso(a):
    lasso_model = make_pipeline(PowerTransformer(),LassoCV(alphas=[a],
                               cv=kfold)).fit(x_train,y_train)
    return cv_rmse(lasso_model).mean()


for i in alpha:
    score=lasso(i)
    print(i," : ",score)

#plt.plot(alpha,alpha_score, label='Lasso')
# Out:
# 5e-05  :  3335.1055971283104
# 0.0003  :  3335.105586995334
# 0.0001  :  3335.1055950988493
# 0.0005  :  3335.1055788659933
# 0.0007  :  3335.105570778452
# 0.0009  :  3335.105562649289
# 0.01  :  3335.105194166887

# %%
###RIDGE###

#HyperParameter Tuning

alpha2=[14.5,14.6,14.7,14.8,14.9,15.0,15.0,15.2,15.3,15.4,15.5]

for i in scaler:
    ridge_model = make_pipeline(i, RidgeCV(alphas=alpha2)).fit(x_train,y_train)
    print("The RMSE value of {0} is ".format(i),cv_rmse(ridge_model).mean())
# Out:
# The RMSE value of MinMaxScaler(copy=True, feature_range=(0, 1)) is  3344.0724205199303
# The RMSE value of StandardScaler(copy=True, with_mean=True, with_std=True) is  3340.21488858754
# The RMSE value of RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True) is  3340.1609759023972
# The RMSE value of PowerTransformer(copy=True, method='yeo-johnson', standardize=True) is  3335.038782557765

# %%
#Finding the best alpha value using powertransformer

def ridge(a):
    ridge_model = make_pipeline(PowerTransformer(),RidgeCV(alphas=[a],
                               cv=kfold)).fit(x_train,y_train)
    return cv_rmse(ridge_model).mean()


for i in alpha2:
    score_r=ridge(i)
    print(i," : ",score_r)
    
#As alph value increases RMSE score is getting better
# Out:
# 14.5  :  3335.042442630048
# 14.6  :  3335.0420726957777
# 14.7  :  3335.04170363551
# 14.8  :  3335.0413354487473
# 14.9  :  3335.0409681349906
# 15.0  :  3335.0406016937427
# 15.0  :  3335.0406016937427
# 15.2  :  3335.039871426786
# 15.3  :  3335.0395076000846
# 15.4  :  3335.039144643906
# 15.5  :  3335.0387825577545

# %%
###ElasticNetCV###
def elastic():
    
    elastic = make_pipeline(PowerTransformer(),ElasticNetCV()).fit(x_train,y_train)
    return cv_rmse(elastic).mean()

elastic()#This algorithm works better for Big datasets
# Out:
# 3705.2473288321025

# %%
###XGBOOST###

xgb=XGBRegressor(n_estimators=200,gamma=0,max_depth=10,objective="reg:linear")
xgb.fit(x_train,y_train)
print(cv_rmse(xgb).mean())
warnings.filterwarnings("ignore")
# Out:
# [19:29:08] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:20] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:30] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:40] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:53] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:13] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:23] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:37] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:48] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:59] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:31:08] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:31:17] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:31:26] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:31:35] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:31:44] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:31:54] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:32:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:32:18] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:32:27] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:32:36] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:32:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:33:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:33:12] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:33:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:33:31] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:33:44] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:33:55] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:34:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:34:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:34:25] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:34:35] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:34:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:34:57] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:35:07] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:35:17] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:35:29] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:35:39] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:35:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:35:59] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:36:08] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:36:18] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:36:29] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:36:39] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:36:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:37:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:37:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:37:20] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:37:30] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:37:41] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:37:50] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2725.5376179446703

# %%
#XGBOOST is the best fot for this model
y_pred = xgb.predict(x_test)
